// %%
import java.util.Scanner;
Scanner in = new Scanner(System.in);
String nama, alamat;
int saldo1, norek, pin;
String nasabah [] = new String[10];
int saldo [] = new int[10]; 
String laporan [][] = new String [10][2];
int size = 0;
System.out.println("============ SELAMAT DATANG DI BANK S ==========");
        System.out.println("1. Input data Nasabah ");
        System.out.println("2. Lihat Data Nasabah ");
        System.out.println("3. Pilih jenis tabungan Tabungan ");
        System.out.println("4. exit ");
        System.out.println("Masukkan Perintah : ");
        int cmd = in.nextInt();
        
        if(cmd==1){
            System.out.println("Masukkan nama :");
            in.nextLine();
            nama = in.nextLine();
            System.out.println("Masukkan Alamat :");
            alamat = in.nextLine();
            System.out.println("Masukkan No. Rekening :");
            norek = in.nextInt();
            System.out.println("Masukkan Pin : ");
            pin = in.nextInt();
            System.out.println("Masukkan Saldo : ");
            saldo1 = in.nextInt();
        }else if(cmd==2){
            System.out.println(nama);
            System.out.println(alamat);
            System.out.println(norek);
            System.out.println(pin);
            System.out.println(saldo);
        }else if(cmd==3){
            System.out.println("1. Tabungan Taplus");
            System.out.println("2. Tabungan Pintar");
            System.out.println("3. Tabungan anak");
            int jenistabungan = in.nextInt();
            if(jenistabungan == 1){
                int taplus = 15000;
                System.out.println("Anda akan dikenakan biaya pajak sebesar "+taplus);
            }else if(jenistabungan == 2){
                int pintar = 10000;
                System.out.println("Anda akan dikenakan biaya pajak sebesar "+pintar);
            }else if(jenistabungan == 3){
                int anak = 5000;
                System.out.println("Anda akan dikenakan biaya pajak sebesar "+anak);
            }
        }else if(cmd==4){
            System.out.println("Terimakasih");
        }
int setor, ambil, transfer;
        System.out.println("============ Tabungan ==========");
        System.out.println("1. Cek saldo ");
        System.out.println("2. Setor tabungan ");
        System.out.println("3. Ambil tabungan ");
        System.out.println("4. Transfer ");
        System.out.println("5. Cetak laporan ");
        System.out.println("Masukkan Perintah : ");
        int cmd1 = in.nextInt();
        if(cmd1==1){
            System.out.println("Jumlah saldo anda sebesar"+saldo1);
        }else if(cmd1==2){
           System.out.println("Masukkan nama:");
           in.nextLine();
           String nama = in.nextLine();
           System.out.println("Masukkan Jumlah setoran :");
           setor = in.nextInt();
           saldo1 = saldo1 + setor;
           System.out.println("Jumlah saldo anda saat ini : "+saldo1);
        }else if(cmd1==3){
           System.out.println("Masukkan nama");
           in.nextLine();
           String nama = in.nextLine();
           System.out.println("Masukkan jumlah uang :");
           ambil = in.nextInt();
           saldo1 = saldo1 - ambil;
           System.out.println("Saldo anda sekarang Rp."+saldo1);
        }else if(cmd1==4){
           System.out.println("Masukkan nama anda");
           String nama = in.nextLine();
           System.out.println("Masukkan Rekening tujuan");
           int rekening = in.nextInt();
           System.out.println("Masukkan jumlah uang");
           int setor = in.nextInt();
           saldo1 = saldo1 - setor;
           System.out.println("Berhasil Melakukan Transfer!!");
           System.out.println("Saldo Anda Sekarang Rp."+saldo1);
        }else if(cmd1==5){
        }
        int indeks = findData(nama);
        int sald = saldo[indeks];
        System.out.println("Nasabah "+nama);
        System.out.println("Saldo anda tersisa Rp."+sald);
}
// Out:
// ============ SELAMAT DATANG DI BANK S ==========
// 1. Input data Nasabah
// 2. Lihat Data Nasabah
// 3. Pilih jenis tabungan Tabungan
// 4. exit
// Masukkan Perintah :
// 1
// Masukkan nama :
// ferly
// Masukkan Alamat :
// asjdj
// Masukkan No. Rekening :
// 123123
// Masukkan Pin :
// 123123
// Masukkan Saldo :
// 10000000
// ============ Tabungan ==========
// 1. Cek saldo
// 2. Setor tabungan
// 3. Ambil tabungan
// 4. Transfer
// 5. Cetak laporan
// Masukkan Perintah :
// 1
// Jumlah saldo anda sebesar10000000
// |           int indeks = findData(nama);
// cannot find symbol
//   symbol:   method findData(java.lang.String)
